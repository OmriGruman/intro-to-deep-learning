# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Convolutional Architectures
# <a id=part3></a>

# %% [markdown]
# In this assignment we will explore convolution networks and the effects of their architecture on accuracy. We'll implement a common block-based deep CNN pattern and we'll perform various experiments on it while varying the architecture. Then we'll implement our own custom architecture to see whether we can get high classification results on CIFAR-10.

# %%
# !pip install tqdm==4.17.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tqdm==4.17.1
#   Downloading tqdm-4.17.1-py2.py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.5 MB/s
# Installing collected packages: tqdm
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.4.1 requires tqdm<5.0.0,>=4.38.0, but you have tqdm 4.17.1 which is incompatible.
# prophet 1.1 requires tqdm>=4.36.1, but you have tqdm 4.17.1 which is incompatible.
# panel 0.12.1 requires tqdm>=4.48.0, but you have tqdm 4.17.1 which is incompatible.
# Successfully installed tqdm-4.17.1

# %%
import os
import re
import sys
import glob
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %%
from google.colab import drive
drive.mount('/content/drive') 
#change this
# %cd /content/drive/MyDrive/Colab Notebooks/MTA/Deep Learning/Assignment 2/CNN

from utils import *
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/MTA/Deep Learning/Assignment 2/CNN

# %% [markdown]
# ## Convolutional layers and networks
# <a id=part3_1></a>

# %% [markdown]
# Convolutional layers are the most essential building blocks of the state of the art deep learning image classification models and also play an important role in many other tasks.
# As we already saw, convolutional layers operate on and produce volumes (3D tensors) of activations.
#
#
# One way to interpret convolutional layers is as a collection of 3D learnable filters,
# each of which operates on a small spatial region of the input volume.
# Each filter is convolved with the input volume ("slides over it"),
# and a dot product is computed at each location followed by a non-linearity which produces one activation.
# All these activations produce a 2D plane known as a **feature map**.
# Multiple feature maps (one for each filter) comprise the output volume.
#
# ![picture](https://sci2lab.github.io/ml_tutorial/images/cnn_convolution_3.png)
#
# A crucial property of convolutional layers is their translation invariance,
# i.e. their ability to detect features regardelss of their spatial location in the input.
#
# Convolutional network architectures usually follow a pattern basic repeating blocks: one or more convolution layers, each followed by a non-linearity (generally ReLU) and then a pooling layer to reduce spatial dimensions. Usually, the number of convolutional filters increases the deeper they are in the network.
# These layers are meant to extract features from the input.
# Then, one or more fully-connected layers is used to combine the extracted features into the required number of output class scores.

# %% [markdown]
# ## Building convolutional networks with PyTorch
# <a id=part3_2></a>

# %% [markdown]
# PyTorch provides all the basic building blocks needed for creating a convolutional arcitecture within the [`torch.nn`](https://pytorch.org/docs/stable/nn.html) package.
# Let's use them to create a basic convolutional network with the following architecture pattern:
#
#     [(CONV -> ReLU)*P -> MaxPool]*(N/P) -> (Linear -> ReLU)*M -> Linear
#
# Here $N$ is the total number of convolutional layers,
# $P$ specifies how many convolutions to perform before each pooling layer
# and $M$ specifies the number of hidden fully-connected layers before the final output layer.

# %% [markdown]
# **TODO**: Complete the implementaion of the `ConvClassifier` class in the `utils/models.py` module.

# %%
from  utils import models
torch.manual_seed(seed)

net = models.ConvClassifier((3,100,100), 10, filters=[32]*4, pool_every=2, hidden_dims=[100]*2).to(device)
print(net)

test_image = torch.randint(low=0, high=256, size=(3, 100, 100), dtype=torch.float).to(device)
test_out = net(test_image.unsqueeze(0))
print('out =', test_out)

expected_out = torch.load('tests/assets/expected_conv_out.pt').to(device)
test.assertLess(torch.norm(test_out - expected_out).item(), 1e-5)
# Out:
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU()
#     (7): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=20000, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# out = tensor([[-0.0868, -0.3790, -0.4341, -0.1236, -0.2160,  0.1683,  0.4739,  0.0750,
#           0.1151, -0.1606]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %% [markdown]
# **Note about running on GPUs**.
#
# Notice how we called `.to(device)` on **both** the model and the input tensor.
# Here the `device` is a `torch.device` object that we created above. If an nvidia GPU is available on the machine you're running this on, the `device` will be `'cuda'`. When you run `.to(device)` on a model, it recursively goes over all the model parameter tensors and copies their memory to the GPU. Similarly, calling `.to(device)` on the input image also copies it.
#
# In order to train on a GPU, you need to make sure to move **all** your tensors to it. You'll get errors if you try to mix CPU and GPU tensors in a computation.

# %%
print(f'This notebook is running with device={device}')
print(f'The model parameter tensors are therefore also on device={next(net.parameters()).device}')
print(f'The test image is therefore also on device={test_image.device}')
# Out:
# This notebook is running with device=cuda
# The model parameter tensors are therefore also on device=cuda:0
# The test image is therefore also on device=cuda:0

# %% [markdown]
# Let's load CIFAR-10 again to use as our dataset.

# %%
data_dir = os.path.expanduser('~/.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')

x0,_ = ds_train[0]
in_size = x0.shape
num_classes = 10
print('input image size =', in_size)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12487508.33it/s]
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples
# input image size = torch.Size([3, 32, 32])

# %% [markdown]
# Now as usual, as a sanity test let's make sure we can overfit a tiny dataset with our model. But first we need to adapt our `Trainer` for PyTorch models.

# %% [markdown]
# **TODO**: Complete the implementaion of the `TorchTrainer` class in the `utils/training.py` module.
# You should implement the funcitons:
# * fit (...)
# * train_batch(...)
# * test_batch(...)

# %%
import utils.training as training
torch.manual_seed(seed)

# Define a tiny part of the CIFAR-10 dataset to overfit it
batch_size = 2
max_batches = 25
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)

# Create model, loss and optimizer instances
model = models.ConvClassifier(in_size, num_classes, filters=[32], pool_every=1, hidden_dims=[100])
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-2, momentum=0.9,)

# Use TorchTrainer to run only the training loop a few times.
trainer = training.TorchTrainer(model, loss_fn, optimizer, device)
best_acc = 0
for i in range(22):
    res = trainer.train_epoch(dl_train, max_batches=max_batches, verbose=(i%2==0))
    best_acc = res.accuracy if res.accuracy > best_acc else best_acc
    
# Test overfitting
test.assertGreaterEqual(best_acc, 95)
# Out:
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# train_batch (Avg. Loss 2.371, Accuracy 6.0): 100%|██████████| 25/25 [00:00<00:00, 266.58it/s]
# train_batch (Avg. Loss 2.238, Accuracy 16.0): 100%|██████████| 25/25 [00:00<00:00, 253.36it/s]
# train_batch (Avg. Loss 2.131, Accuracy 22.0): 100%|██████████| 25/25 [00:00<00:00, 257.65it/s]
# train_batch (Avg. Loss 1.829, Accuracy 34.0): 100%|██████████| 25/25 [00:00<00:00, 224.89it/s]
# train_batch (Avg. Loss 1.050, Accuracy 64.0): 100%|██████████| 25/25 [00:00<00:00, 245.87it/s]
# train_batch (Avg. Loss 1.424, Accuracy 52.0): 100%|██████████| 25/25 [00:00<00:00, 228.88it/s]
# train_batch (Avg. Loss 1.127, Accuracy 66.0): 100%|██████████| 25/25 [00:00<00:00, 216.81it/s]
# train_batch (Avg. Loss 0.693, Accuracy 80.0): 100%|██████████| 25/25 [00:00<00:00, 218.20it/s]
# train_batch (Avg. Loss 0.373, Accuracy 88.0): 100%|██████████| 25/25 [00:00<00:00, 248.66it/s]
# train_batch (Avg. Loss 0.050, Accuracy 96.0): 100%|██████████| 25/25 [00:00<00:00, 245.24it/s]
# train_batch (Avg. Loss 0.004, Accuracy 100.0): 100%|██████████| 25/25 [00:00<00:00, 252.95it/s]

# %% [markdown]
# ## Experimenting with model architectures
# <a id=part3_3></a>

# %% [markdown]
# You will now perform a series of experiments that train various model configurations on a much larger part of the CIFAR-10 dataset.
#
# To perform the experiments, you'll need to use a machine with a GPU since training time might be too long otherwise.

# %% [markdown]
# ### General notes for running experiments
#
# - It's important to give each experiment run a name as specified by the notebook instructions later on. The each run has a `run_name` parameter that will also be the name of the results file which this notebook will expect to load.
#
# - You will implement the code to run the experiments in the `utils/experiments.py` module.

# %% [markdown]
# ### Experiment 1 - Network depth and number of filters

# %% [markdown]
# In this part we will test some different architecture configurations based on our `ConvClassifier`.
# Specifically, we want to try different depths and number of features to see the effects these parameters have on the model's performance.
#
# To do this, we'll define two extra hyperparameters for our model, `K` (`filters_per_layer`) and `L` (`layers_per_block`).
# - `K` is a list, containing the number of filters we want to have in our conv layers.
# - `L` is the number of consecutive layers with the same number of filters to use.
#
# For example, if `K=[32, 64]` and `L=2` it means we want two conv layers with 32 filters followed by two conv layers with 64 filters. The feature-extraction part of our model will therefore be:
#
#     Conv(X,32)->ReLu->Conv(32,32)->ReLU->MaxPool->Conv(32,64)->ReLU->Conv(64,64)->ReLU->MaxPool
#
# We'll try various values of the `K` and `L` parameters in combination and see how each architecture trains.

# %% [markdown]
# First we need to write some code to run the experiment.
#
# **TODO**:
# 1. Implement the `run_experiment()` function in the `utils/experiments.py` module.
# 1. If you haven't done so already, it would be an excellent idea to implement the **early stopping** feature of the `Trainer` class.
#
# The following block tests that your implementation works. It's also meant to show you that each experiment run creates a result file containing the parameters to reproduce and the `FitResult` object for plotting.

# %%
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit

# %%
# Test experiment1 implementation on a few data samples and with a small model
experiments.run_experiment('test_run', seed=seed, bs_train=50, batches=10, epochs=10, early_stopping=5,
                           filters_per_layer=[32], layers_per_block=1, pool_every=1, hidden_dims=[100])

# There should now be a file 'test_run.json' in your `results/` folder.
# We can use it to load the results of the experiment.
cfg, fit_res = load_experiment('results/test_run.json')
_, _ = plot_fit(fit_res)

# And `cfg` contains the exact parameters to reproduce it
print('experiment config: ', cfg)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 1.552, Accuracy 44.2): 100%|██████████| 850/850 [00:04<00:00, 197.06it/s]
# test_batch (Avg. Loss 1.318, Accuracy 54.1): 100%|██████████| 625/625 [00:02<00:00, 292.90it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.286, Accuracy 54.4): 100%|██████████| 850/850 [00:04<00:00, 177.86it/s]
# test_batch (Avg. Loss 1.264, Accuracy 55.0): 100%|██████████| 625/625 [00:02<00:00, 294.24it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.204, Accuracy 57.4): 100%|██████████| 850/850 [00:04<00:00, 172.43it/s]
# test_batch (Avg. Loss 1.175, Accuracy 57.9): 100%|██████████| 625/625 [00:02<00:00, 277.89it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.149, Accuracy 59.6): 100%|██████████| 850/850 [00:05<00:00, 167.33it/s]
# test_batch (Avg. Loss 1.150, Accuracy 59.2): 100%|██████████| 625/625 [00:02<00:00, 300.56it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.100, Accuracy 61.6): 100%|██████████| 850/850 [00:04<00:00, 176.25it/s]
# test_batch (Avg. Loss 1.125, Accuracy 59.6): 100%|██████████| 625/625 [00:02<00:00, 267.54it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.056, Accuracy 63.1): 100%|██████████| 850/850 [00:05<00:00, 168.83it/s]
# test_batch (Avg. Loss 1.086, Accuracy 60.9): 100%|██████████| 625/625 [00:02<00:00, 293.46it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.023, Accuracy 64.1): 100%|██████████| 850/850 [00:04<00:00, 175.42it/s]
# test_batch (Avg. Loss 1.094, Accuracy 60.3): 100%|██████████| 625/625 [00:02<00:00, 306.91it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 0.991, Accuracy 65.1): 100%|██████████| 850/850 [00:04<00:00, 183.13it/s]
# test_batch (Avg. Loss 1.055, Accuracy 62.1): 100%|██████████| 625/625 [00:02<00:00, 289.85it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 0.961, Accuracy 66.4): 100%|██████████| 850/850 [00:04<00:00, 176.42it/s]
# test_batch (Avg. Loss 1.051, Accuracy 62.1): 100%|██████████| 625/625 [00:02<00:00, 285.01it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 0.939, Accuracy 67.1): 100%|██████████| 850/850 [00:04<00:00, 174.57it/s]
# test_batch (Avg. Loss 1.051, Accuracy 63.1): 100%|██████████| 625/625 [00:02<00:00, 300.10it/s]
# test_batch (Avg. Loss 1.069, Accuracy 62.6): 100%|██████████| 834/834 [00:04<00:00, 185.37it/s]
# ==================== Test Results ====================
# Test Accuracy: 62.57
# Test Loss: 1.0692894583661778
# ======================================================
# *** Output file ./results/test_run.json written
# experiment config:  {'run_name': 'test_run', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10, 'epochs': 10, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.001, 'filters_per_layer': [32], 'layers_per_block': 1, 'pool_every': 1, 'hidden_dims': [100], 'ycn': False, 'kw': {}}

# %% [markdown]
# We'll use the following function to load multiple experiment results and plot them together.

# %%
def plot_exp_results(filename_pattern, results_dir='results'):
    fig = None
    result_files = glob.glob(os.path.join(results_dir, filename_pattern))
    result_files.sort()
    if len(result_files) == 0:
        print(f'No results found for pattern {filename_pattern}.', file=sys.stderr)
        return
    for filepath in result_files:
        m = re.match('exp\d_(\d_)?(.*)\.json', os.path.basename(filepath))
        cfg, fit_res = load_experiment(filepath)
        fig, axes = plot_fit(fit_res, fig, legend=m[2],log_loss=True)
    del cfg['filters_per_layer']
    del cfg['layers_per_block']
    print('common config: ', cfg)

# %% [markdown]
# #### Experiment 1.1: Varying the network depth (`L`)

# %% [markdown]
# First, we'll test the effect of the network depth on training.
#
# **Configuratons**:
# - `K=32` fixed, with `L=2,4,8,16` varying per run
# - `K=64` fixed, with `L=2,4,8,16` varying per run
#
# So 8 different runs in total.
#
# **Naming runs**:
# Each run should be named `exp1_1_K{}_L{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_1_K32_L2`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
import utils.experiments as experiments
from utils.experiments import load_experiment
from utils.plot import plot_fit

# %%
for l in [2,4,8,16]:
    # Test experiment1 implementation on a few data samples and with a small model
    experiments.run_experiment(f'exp1_1_K32_L{l}',
                               seed=seed,
                               bs_train=50,
                               batches=10000,
                               epochs=30, 
                               early_stopping=5,
                               reg=2e-3,
                               lr=1e-3,
                               filters_per_layer=[32],
                               layers_per_block=l,
                               pool_every=4,
                               hidden_dims=[100, 100])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.570, Accuracy 42.6): 100%|██████████| 850/850 [00:06<00:00, 141.24it/s]
# test_batch (Avg. Loss 1.382, Accuracy 50.5): 100%|██████████| 625/625 [00:02<00:00, 280.41it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.340, Accuracy 51.9): 100%|██████████| 850/850 [00:06<00:00, 130.15it/s]
# test_batch (Avg. Loss 1.323, Accuracy 51.1): 100%|██████████| 625/625 [00:02<00:00, 289.09it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.243, Accuracy 55.3): 100%|██████████| 850/850 [00:06<00:00, 134.51it/s]
# test_batch (Avg. Loss 1.216, Accuracy 55.8): 100%|██████████| 625/625 [00:02<00:00, 293.90it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.177, Accuracy 58.0): 100%|██████████| 850/850 [00:06<00:00, 134.90it/s]
# test_batch (Avg. Loss 1.177, Accuracy 57.7): 100%|██████████| 625/625 [00:02<00:00, 300.33it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.110, Accuracy 60.4): 100%|██████████| 850/850 [00:06<00:00, 131.45it/s]
# test_batch (Avg. Loss 1.136, Accuracy 58.8): 100%|██████████| 625/625 [00:02<00:00, 281.23it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.051, Accuracy 63.1): 100%|██████████| 850/850 [00:06<00:00, 133.44it/s]
# test_batch (Avg. Loss 1.104, Accuracy 59.7): 100%|██████████| 625/625 [00:02<00:00, 308.11it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.008, Accuracy 64.0): 100%|██████████| 850/850 [00:06<00:00, 131.28it/s]
# test_batch (Avg. Loss 1.091, Accuracy 60.6): 100%|██████████| 625/625 [00:02<00:00, 280.97it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.959, Accuracy 66.0): 100%|██████████| 850/850 [00:06<00:00, 138.87it/s]
# test_batch (Avg. Loss 1.084, Accuracy 61.1): 100%|██████████| 625/625 [00:02<00:00, 280.50it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.921, Accuracy 67.5): 100%|██████████| 850/850 [00:06<00:00, 130.35it/s]
# test_batch (Avg. Loss 1.072, Accuracy 61.4): 100%|██████████| 625/625 [00:02<00:00, 296.47it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.883, Accuracy 68.8): 100%|██████████| 850/850 [00:06<00:00, 132.76it/s]
# test_batch (Avg. Loss 1.025, Accuracy 63.9): 100%|██████████| 625/625 [00:02<00:00, 276.89it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.855, Accuracy 69.7): 100%|██████████| 850/850 [00:06<00:00, 132.90it/s]
# test_batch (Avg. Loss 1.060, Accuracy 62.6): 100%|██████████| 625/625 [00:02<00:00, 274.54it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.820, Accuracy 70.8): 100%|██████████| 850/850 [00:06<00:00, 129.26it/s]
# test_batch (Avg. Loss 1.013, Accuracy 63.8): 100%|██████████| 625/625 [00:02<00:00, 283.90it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.794, Accuracy 71.8): 100%|██████████| 850/850 [00:06<00:00, 130.95it/s]
# test_batch (Avg. Loss 1.028, Accuracy 63.8): 100%|██████████| 625/625 [00:02<00:00, 282.96it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.766, Accuracy 73.1): 100%|██████████| 850/850 [00:06<00:00, 128.53it/s]
# test_batch (Avg. Loss 1.026, Accuracy 64.3): 100%|██████████| 625/625 [00:02<00:00, 281.43it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.738, Accuracy 74.1): 100%|██████████| 850/850 [00:06<00:00, 127.13it/s]
# test_batch (Avg. Loss 1.028, Accuracy 64.1): 100%|██████████| 625/625 [00:02<00:00, 267.74it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.720, Accuracy 74.3): 100%|██████████| 850/850 [00:06<00:00, 132.43it/s]
# test_batch (Avg. Loss 1.029, Accuracy 64.1): 100%|██████████| 625/625 [00:02<00:00, 268.80it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.694, Accuracy 75.3): 100%|██████████| 850/850 [00:06<00:00, 128.96it/s]
# test_batch (Avg. Loss 1.053, Accuracy 63.3): 100%|██████████| 625/625 [00:02<00:00, 267.10it/s]
# test_batch (Avg. Loss 1.066, Accuracy 63.2): 100%|██████████| 834/834 [00:04<00:00, 176.12it/s]
# ==================== Test Results ====================
# Test Accuracy: 63.22
# Test Loss: 1.0657934610702866
# ======================================================
# *** Output file ./results/exp1_1_K32_L2.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.712, Accuracy 37.0): 100%|██████████| 850/850 [00:06<00:00, 133.21it/s]
# test_batch (Avg. Loss 1.514, Accuracy 43.8): 100%|██████████| 625/625 [00:02<00:00, 267.38it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.423, Accuracy 48.3): 100%|██████████| 850/850 [00:07<00:00, 117.24it/s]
# test_batch (Avg. Loss 1.350, Accuracy 50.8): 100%|██████████| 625/625 [00:02<00:00, 264.26it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.270, Accuracy 54.2): 100%|██████████| 850/850 [00:07<00:00, 116.50it/s]
# test_batch (Avg. Loss 1.206, Accuracy 55.3): 100%|██████████| 625/625 [00:02<00:00, 254.89it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.163, Accuracy 58.2): 100%|██████████| 850/850 [00:07<00:00, 117.01it/s]
# test_batch (Avg. Loss 1.134, Accuracy 59.4): 100%|██████████| 625/625 [00:02<00:00, 245.53it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.087, Accuracy 61.0): 100%|██████████| 850/850 [00:07<00:00, 119.35it/s]
# test_batch (Avg. Loss 1.109, Accuracy 60.5): 100%|██████████| 625/625 [00:02<00:00, 255.57it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.042, Accuracy 63.0): 100%|██████████| 850/850 [00:07<00:00, 118.16it/s]
# test_batch (Avg. Loss 1.056, Accuracy 62.4): 100%|██████████| 625/625 [00:02<00:00, 254.20it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.998, Accuracy 64.8): 100%|██████████| 850/850 [00:07<00:00, 116.65it/s]
# test_batch (Avg. Loss 1.023, Accuracy 63.4): 100%|██████████| 625/625 [00:02<00:00, 258.12it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.955, Accuracy 66.0): 100%|██████████| 850/850 [00:07<00:00, 117.82it/s]
# test_batch (Avg. Loss 1.014, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 255.64it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.921, Accuracy 67.3): 100%|██████████| 850/850 [00:07<00:00, 117.77it/s]
# test_batch (Avg. Loss 1.053, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 263.97it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.887, Accuracy 68.5): 100%|██████████| 850/850 [00:07<00:00, 118.10it/s]
# test_batch (Avg. Loss 1.016, Accuracy 64.5): 100%|██████████| 625/625 [00:02<00:00, 251.55it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.848, Accuracy 69.9): 100%|██████████| 850/850 [00:07<00:00, 117.85it/s]
# test_batch (Avg. Loss 1.046, Accuracy 62.7): 100%|██████████| 625/625 [00:02<00:00, 261.12it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.814, Accuracy 71.1): 100%|██████████| 850/850 [00:07<00:00, 118.20it/s]
# test_batch (Avg. Loss 1.090, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 251.61it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.790, Accuracy 72.1): 100%|██████████| 850/850 [00:07<00:00, 115.77it/s]
# test_batch (Avg. Loss 0.933, Accuracy 67.1): 100%|██████████| 625/625 [00:02<00:00, 270.53it/s]
# --- EPOCH 14/30 ---
# test_batch (Avg. Loss 0.921, Accuracy 67.5): 100%|██████████| 625/625 [00:02<00:00, 281.67it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.731, Accuracy 74.0): 100%|██████████| 850/850 [00:07<00:00, 117.73it/s]
# test_batch (Avg. Loss 0.954, Accuracy 66.6): 100%|██████████| 625/625 [00:02<00:00, 262.88it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.713, Accuracy 74.7): 100%|██████████| 850/850 [00:07<00:00, 115.91it/s]
# test_batch (Avg. Loss 1.003, Accuracy 66.3): 100%|██████████| 625/625 [00:02<00:00, 254.44it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.685, Accuracy 75.7): 100%|██████████| 850/850 [00:07<00:00, 116.67it/s]
# test_batch (Avg. Loss 0.973, Accuracy 66.8): 100%|██████████| 625/625 [00:02<00:00, 267.11it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.663, Accuracy 76.6): 100%|██████████| 850/850 [00:07<00:00, 117.25it/s]
# test_batch (Avg. Loss 0.958, Accuracy 66.1): 100%|██████████| 625/625 [00:02<00:00, 263.76it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.643, Accuracy 77.3): 100%|██████████| 850/850 [00:07<00:00, 116.87it/s]
# test_batch (Avg. Loss 0.992, Accuracy 66.9): 100%|██████████| 625/625 [00:02<00:00, 263.59it/s]
# test_batch (Avg. Loss 1.014, Accuracy 66.0): 100%|██████████| 834/834 [00:05<00:00, 165.90it/s]
# ==================== Test Results ====================
# Test Accuracy: 66.04
# Test Loss: 1.0144387948141396
# ======================================================
# *** Output file ./results/exp1_1_K32_L4.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:08<00:00, 98.42it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:02<00:00, 227.30it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:08<00:00, 95.16it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 221.90it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:08<00:00, 95.04it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 230.43it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:08<00:00, 96.19it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 227.29it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:08<00:00, 96.52it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 214.54it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:08<00:00, 96.28it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 225.38it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:05<00:00, 158.75it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.302644456033226
# ======================================================
# *** Output file ./results/exp1_1_K32_L8.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (18): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU()
#     (20): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU()
#     (22): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU()
#     (24): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): ReLU()
#     (29): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): ReLU()
#     (31): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (32): ReLU()
#     (33): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): ReLU()
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=128, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:12<00:00, 68.79it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 186.78it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:12<00:00, 67.57it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 187.61it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:12<00:00, 69.73it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 186.12it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:12<00:00, 68.50it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 185.60it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:12<00:00, 68.36it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 190.93it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:12<00:00, 67.49it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 182.14it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:12<00:00, 67.93it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 196.64it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:12<00:00, 68.66it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 183.84it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 135.46it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.302638965544941
# ======================================================
# *** Output file ./results/exp1_1_K32_L16.json written

# %%
plot_exp_results('exp1_1_K32*.json')
# Out:
# common config:  {'run_name': 'exp1_1_K32_L8', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
for l in [2,4,8,16]:
    # Test experiment1 implementation on a few data samples and with a small model
    experiments.run_experiment(f'exp1_1_K64_L{l}',
                               seed=seed,
                               bs_train=50,
                               batches=10000,
                               epochs=30, 
                               early_stopping=5,
                               reg=2e-3,
                               lr=1e-3,
                               filters_per_layer=[64],
                               layers_per_block=l,
                               pool_every=4,
                               hidden_dims=[100, 100])
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=65536, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.549, Accuracy 43.4): 100%|██████████| 850/850 [00:08<00:00, 95.60it/s]
# test_batch (Avg. Loss 1.333, Accuracy 51.7): 100%|██████████| 625/625 [00:02<00:00, 280.35it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.294, Accuracy 53.6): 100%|██████████| 850/850 [00:09<00:00, 93.78it/s]
# test_batch (Avg. Loss 1.209, Accuracy 56.4): 100%|██████████| 625/625 [00:02<00:00, 264.17it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.178, Accuracy 58.0): 100%|██████████| 850/850 [00:09<00:00, 93.78it/s]
# test_batch (Avg. Loss 1.202, Accuracy 57.1): 100%|██████████| 625/625 [00:02<00:00, 275.75it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.095, Accuracy 60.8): 100%|██████████| 850/850 [00:09<00:00, 93.50it/s]
# test_batch (Avg. Loss 1.154, Accuracy 57.8): 100%|██████████| 625/625 [00:02<00:00, 282.86it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.027, Accuracy 63.6): 100%|██████████| 850/850 [00:09<00:00, 93.67it/s]
# test_batch (Avg. Loss 1.065, Accuracy 62.1): 100%|██████████| 625/625 [00:02<00:00, 281.94it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.2): 100%|██████████| 850/850 [00:09<00:00, 92.95it/s]
# test_batch (Avg. Loss 1.060, Accuracy 62.1): 100%|██████████| 625/625 [00:02<00:00, 293.32it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.935, Accuracy 66.6): 100%|██████████| 850/850 [00:09<00:00, 93.48it/s]
# test_batch (Avg. Loss 1.060, Accuracy 62.5): 100%|██████████| 625/625 [00:02<00:00, 289.93it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.892, Accuracy 68.3): 100%|██████████| 850/850 [00:09<00:00, 92.03it/s]
# test_batch (Avg. Loss 1.027, Accuracy 63.0): 100%|██████████| 625/625 [00:02<00:00, 276.56it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.857, Accuracy 69.7): 100%|██████████| 850/850 [00:09<00:00, 93.94it/s]
# test_batch (Avg. Loss 1.073, Accuracy 61.9): 100%|██████████| 625/625 [00:02<00:00, 271.91it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.817, Accuracy 71.2): 100%|██████████| 850/850 [00:09<00:00, 91.91it/s]
# test_batch (Avg. Loss 0.987, Accuracy 65.3): 100%|██████████| 625/625 [00:02<00:00, 264.26it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.783, Accuracy 72.4): 100%|██████████| 850/850 [00:09<00:00, 92.49it/s]
# test_batch (Avg. Loss 1.033, Accuracy 64.0): 100%|██████████| 625/625 [00:02<00:00, 279.48it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.754, Accuracy 73.5): 100%|██████████| 850/850 [00:09<00:00, 91.99it/s]
# test_batch (Avg. Loss 1.023, Accuracy 64.0): 100%|██████████| 625/625 [00:02<00:00, 280.27it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.723, Accuracy 74.5): 100%|██████████| 850/850 [00:09<00:00, 93.41it/s]
# test_batch (Avg. Loss 1.035, Accuracy 63.5): 100%|██████████| 625/625 [00:02<00:00, 269.22it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.690, Accuracy 75.8): 100%|██████████| 850/850 [00:09<00:00, 90.29it/s]
# test_batch (Avg. Loss 1.001, Accuracy 65.3): 100%|██████████| 625/625 [00:02<00:00, 245.99it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.669, Accuracy 76.4): 100%|██████████| 850/850 [00:09<00:00, 90.08it/s]
# test_batch (Avg. Loss 1.070, Accuracy 63.0): 100%|██████████| 625/625 [00:02<00:00, 256.88it/s]
# test_batch (Avg. Loss 1.063, Accuracy 63.3): 100%|██████████| 834/834 [00:05<00:00, 159.23it/s]
# ==================== Test Results ====================
# Test Accuracy: 63.3
# Test Loss: 1.0630137831580153
# ======================================================
# *** Output file ./results/exp1_1_K64_L2.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.748, Accuracy 35.3): 100%|██████████| 850/850 [00:12<00:00, 69.88it/s]
# test_batch (Avg. Loss 1.534, Accuracy 43.0): 100%|██████████| 625/625 [00:02<00:00, 242.87it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.439, Accuracy 47.8): 100%|██████████| 850/850 [00:12<00:00, 70.36it/s]
# test_batch (Avg. Loss 1.343, Accuracy 51.0): 100%|██████████| 625/625 [00:02<00:00, 230.61it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.256, Accuracy 55.1): 100%|██████████| 850/850 [00:12<00:00, 70.16it/s]
# test_batch (Avg. Loss 1.243, Accuracy 55.0): 100%|██████████| 625/625 [00:02<00:00, 228.62it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.121, Accuracy 59.8): 100%|██████████| 850/850 [00:12<00:00, 69.84it/s]
# test_batch (Avg. Loss 1.118, Accuracy 59.9): 100%|██████████| 625/625 [00:02<00:00, 233.25it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.024, Accuracy 63.4): 100%|██████████| 850/850 [00:12<00:00, 69.39it/s]
# test_batch (Avg. Loss 1.115, Accuracy 60.2): 100%|██████████| 625/625 [00:02<00:00, 229.00it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.958, Accuracy 65.9): 100%|██████████| 850/850 [00:12<00:00, 69.76it/s]
# test_batch (Avg. Loss 1.031, Accuracy 62.6): 100%|██████████| 625/625 [00:02<00:00, 230.56it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.902, Accuracy 68.1): 100%|██████████| 850/850 [00:12<00:00, 69.94it/s]
# test_batch (Avg. Loss 0.992, Accuracy 65.4): 100%|██████████| 625/625 [00:02<00:00, 222.15it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.858, Accuracy 69.7): 100%|██████████| 850/850 [00:12<00:00, 70.05it/s]
# test_batch (Avg. Loss 0.970, Accuracy 64.8): 100%|██████████| 625/625 [00:02<00:00, 240.22it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.819, Accuracy 71.0): 100%|██████████| 850/850 [00:12<00:00, 70.13it/s]
# test_batch (Avg. Loss 0.975, Accuracy 65.8): 100%|██████████| 625/625 [00:02<00:00, 225.69it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.781, Accuracy 72.3): 100%|██████████| 850/850 [00:12<00:00, 71.77it/s]
# test_batch (Avg. Loss 0.922, Accuracy 67.4): 100%|██████████| 625/625 [00:02<00:00, 228.32it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.756, Accuracy 73.3): 100%|██████████| 850/850 [00:12<00:00, 69.62it/s]
# test_batch (Avg. Loss 0.911, Accuracy 67.9): 100%|██████████| 625/625 [00:02<00:00, 231.34it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.719, Accuracy 74.7): 100%|██████████| 850/850 [00:12<00:00, 69.26it/s]
# test_batch (Avg. Loss 0.948, Accuracy 67.3): 100%|██████████| 625/625 [00:02<00:00, 239.84it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.691, Accuracy 75.7): 100%|██████████| 850/850 [00:12<00:00, 69.01it/s]
# test_batch (Avg. Loss 0.946, Accuracy 66.7): 100%|██████████| 625/625 [00:02<00:00, 237.52it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.663, Accuracy 76.6): 100%|██████████| 850/850 [00:12<00:00, 69.75it/s]
# test_batch (Avg. Loss 0.928, Accuracy 67.6): 100%|██████████| 625/625 [00:02<00:00, 234.65it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.634, Accuracy 77.4): 100%|██████████| 850/850 [00:12<00:00, 69.21it/s]
# test_batch (Avg. Loss 0.975, Accuracy 66.7): 100%|██████████| 625/625 [00:02<00:00, 215.87it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.615, Accuracy 78.4): 100%|██████████| 850/850 [00:12<00:00, 70.12it/s]
# test_batch (Avg. Loss 0.951, Accuracy 67.8): 100%|██████████| 625/625 [00:02<00:00, 220.60it/s]
# test_batch (Avg. Loss 0.954, Accuracy 67.9): 100%|██████████| 834/834 [00:05<00:00, 155.35it/s]
# ==================== Test Results ====================
# Test Accuracy: 67.94
# Test Loss: 0.9542107146671064
# ======================================================
# *** Output file ./results/exp1_1_K64_L4.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 59.10it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.5): 100%|██████████| 625/625 [00:02<00:00, 215.65it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 58.61it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:02<00:00, 213.77it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:14<00:00, 59.05it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:02<00:00, 223.68it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:14<00:00, 58.65it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:02<00:00, 217.03it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:14<00:00, 58.86it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:02<00:00, 213.73it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:14<00:00, 59.69it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:02<00:00, 231.70it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:05<00:00, 146.22it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.3026149913275558
# ======================================================
# *** Output file ./results/exp1_1_K64_L8.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (18): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (19): ReLU()
#     (20): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (21): ReLU()
#     (22): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (23): ReLU()
#     (24): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU()
#     (26): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (27): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (28): ReLU()
#     (29): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (30): ReLU()
#     (31): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (32): ReLU()
#     (33): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (34): ReLU()
#     (35): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=256, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 51.73it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 177.08it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 51.62it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 180.78it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 51.18it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 177.04it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:16<00:00, 51.02it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 174.45it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:16<00:00, 50.62it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 181.83it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:16<00:00, 51.61it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 168.48it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:16<00:00, 51.09it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 176.82it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 850/850 [00:16<00:00, 51.80it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 169.93it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:16<00:00, 51.68it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 175.21it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 126.31it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.302621938341813
# ======================================================
# *** Output file ./results/exp1_1_K64_L16.json written

# %%
plot_exp_results('exp1_1_K64*.json')
# Out:
# common config:  {'run_name': 'exp1_1_K64_L8', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %% [markdown]
# ### Question 1
#
# Analyze your results from experiment 1.1. In particular,
# 1.  Explain the effect of depth on the accuracy. What depth produces the best results and why do you think that's the case?
# 1. Were there values of `L` for which the network wasn't trainable? what causes this? Suggest two things which may be done to resolve it at least partially.

# %% [markdown]
# **ANSWER**:
#
# We ran some experiments on different conv nets, using a fixed kernel size of either 32 or 64, and changing the depth between 2, 4, 8, and 16.
#
# 1. It seems that the 4-layer nets performed better an were 5% more accurate than the 2-layer nets on the test set. The increase in performance might be tied to the ability of the 4-layer nets to learn better and more complex features. That is thanks to the larger number of weight they had and especially the larger amount of layers, but could be also the addition of the max pooling layer which was absent in the 2-layer nets.
#
# 2. For both kernel sizes, the nets with layer numbers 8 and 16 were not trainable, and plotted a practically flat line for the loss and accuracy. That might be a case of vanishing gradients, caused by the large number of gradients that were multiplied together in the backpropagation process. First, I would consider add a batch normalization once every few layers, in order to normalize the values being fed into the net. This way the gradients will stabilize and not vanish. Another way is adding residual connections which will result in higher gradients, and keep them from vanishing.

# %% [markdown]
# #### Experiment 1.2: Varying the number of filters per layer (`K`)

# %% [markdown]
# Now we'll test the effect of the number of convolutional filters in each layer.
#
# **Configuratons**:
# - `L=2` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=4` fixed, with `K=[32],[64],[128],[256]` varying per run.
# - `L=8` fixed, with `K=[32],[64],[128],[256]` varying per run.
#
# So 12 different runs in total. To clarify, each run `K` takes the value of a list with a single element.
#
# **Naming runs**:
# Each run should be named `exp1_2_L{}_K{}` where the braces are placeholders for the values. For example, the first run should be named `exp1_2_L2_K32`.

# %% [markdown]
# **TODO**: Run the experiment on the above configuration. Make sure the result file names are as expected. Use the following blocks to display the results.

# %%
for l in [2,4,8]:
    for k in [32,64,128,256]:
        # Test experiment1 implementation on a few data samples and with a small model
        experiments.run_experiment(f'exp1_2_L{l}_K{k}',
                                   seed=seed,
                                   bs_train=50,
                                   batches=10000,
                                   epochs=30, 
                                   early_stopping=5,
                                   reg=2e-3,
                                   lr=1e-3,
                                   filters_per_layer=[k],
                                   layers_per_block=l,
                                   pool_every=4, 
                                   hidden_dims=[100, 100])
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to /root/.pytorch-datasets/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting /root/.pytorch-datasets/cifar-10-python.tar.gz to /root/.pytorch-datasets
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.570, Accuracy 42.7): 100%|██████████| 850/850 [00:14<00:00, 59.75it/s]
# test_batch (Avg. Loss 1.383, Accuracy 50.5): 100%|██████████| 625/625 [00:03<00:00, 194.33it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.337, Accuracy 51.8): 100%|██████████| 850/850 [00:07<00:00, 110.59it/s]
# test_batch (Avg. Loss 1.318, Accuracy 52.4): 100%|██████████| 625/625 [00:03<00:00, 198.64it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.239, Accuracy 55.6): 100%|██████████| 850/850 [00:07<00:00, 111.55it/s]
# test_batch (Avg. Loss 1.217, Accuracy 55.9): 100%|██████████| 625/625 [00:03<00:00, 191.47it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.173, Accuracy 58.3): 100%|██████████| 850/850 [00:07<00:00, 111.87it/s]
# test_batch (Avg. Loss 1.173, Accuracy 58.0): 100%|██████████| 625/625 [00:03<00:00, 195.15it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.108, Accuracy 60.3): 100%|██████████| 850/850 [00:07<00:00, 110.09it/s]
# test_batch (Avg. Loss 1.137, Accuracy 58.7): 100%|██████████| 625/625 [00:03<00:00, 199.97it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.046, Accuracy 63.1): 100%|██████████| 850/850 [00:07<00:00, 111.48it/s]
# test_batch (Avg. Loss 1.093, Accuracy 60.4): 100%|██████████| 625/625 [00:03<00:00, 198.32it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.995, Accuracy 64.7): 100%|██████████| 850/850 [00:07<00:00, 111.16it/s]
# test_batch (Avg. Loss 1.067, Accuracy 61.8): 100%|██████████| 625/625 [00:03<00:00, 194.56it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.944, Accuracy 66.7): 100%|██████████| 850/850 [00:07<00:00, 110.35it/s]
# test_batch (Avg. Loss 1.044, Accuracy 63.4): 100%|██████████| 625/625 [00:03<00:00, 199.54it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.907, Accuracy 67.9): 100%|██████████| 850/850 [00:07<00:00, 109.33it/s]
# test_batch (Avg. Loss 1.072, Accuracy 61.9): 100%|██████████| 625/625 [00:03<00:00, 198.80it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.873, Accuracy 69.3): 100%|██████████| 850/850 [00:08<00:00, 104.48it/s]
# test_batch (Avg. Loss 1.026, Accuracy 63.7): 100%|██████████| 625/625 [00:03<00:00, 202.79it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.838, Accuracy 70.4): 100%|██████████| 850/850 [00:07<00:00, 109.24it/s]
# test_batch (Avg. Loss 1.032, Accuracy 63.4): 100%|██████████| 625/625 [00:03<00:00, 194.73it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.808, Accuracy 71.8): 100%|██████████| 850/850 [00:07<00:00, 109.60it/s]
# test_batch (Avg. Loss 1.016, Accuracy 64.2): 100%|██████████| 625/625 [00:03<00:00, 195.39it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.780, Accuracy 72.5): 100%|██████████| 850/850 [00:07<00:00, 108.04it/s]
# test_batch (Avg. Loss 1.042, Accuracy 63.7): 100%|██████████| 625/625 [00:03<00:00, 197.17it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.753, Accuracy 73.7): 100%|██████████| 850/850 [00:07<00:00, 108.10it/s]
# test_batch (Avg. Loss 1.038, Accuracy 64.1): 100%|██████████| 625/625 [00:03<00:00, 191.98it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.726, Accuracy 74.4): 100%|██████████| 850/850 [00:07<00:00, 109.47it/s]
# test_batch (Avg. Loss 1.063, Accuracy 63.5): 100%|██████████| 625/625 [00:03<00:00, 194.39it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.700, Accuracy 75.3): 100%|██████████| 850/850 [00:07<00:00, 106.77it/s]
# test_batch (Avg. Loss 1.108, Accuracy 62.9): 100%|██████████| 625/625 [00:03<00:00, 189.97it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.676, Accuracy 76.1): 100%|██████████| 850/850 [00:07<00:00, 108.87it/s]
# test_batch (Avg. Loss 1.085, Accuracy 63.0): 100%|██████████| 625/625 [00:03<00:00, 198.30it/s]
# test_batch (Avg. Loss 1.084, Accuracy 63.0): 100%|██████████| 834/834 [00:06<00:00, 134.27it/s]
# ==================== Test Results ====================
# Test Accuracy: 62.99
# Test Loss: 1.0835131028626892
# ======================================================
# *** Output file ./results/exp1_2_L2_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=65536, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.549, Accuracy 43.7): 100%|██████████| 850/850 [00:10<00:00, 83.19it/s]
# test_batch (Avg. Loss 1.330, Accuracy 52.0): 100%|██████████| 625/625 [00:03<00:00, 191.49it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.293, Accuracy 53.4): 100%|██████████| 850/850 [00:10<00:00, 81.03it/s]
# test_batch (Avg. Loss 1.204, Accuracy 56.4): 100%|██████████| 625/625 [00:03<00:00, 206.14it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.174, Accuracy 58.3): 100%|██████████| 850/850 [00:10<00:00, 81.01it/s]
# test_batch (Avg. Loss 1.182, Accuracy 58.1): 100%|██████████| 625/625 [00:03<00:00, 208.10it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.087, Accuracy 61.1): 100%|██████████| 850/850 [00:10<00:00, 82.83it/s]
# test_batch (Avg. Loss 1.156, Accuracy 57.6): 100%|██████████| 625/625 [00:03<00:00, 197.21it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.024, Accuracy 63.6): 100%|██████████| 850/850 [00:10<00:00, 82.38it/s]
# test_batch (Avg. Loss 1.070, Accuracy 61.5): 100%|██████████| 625/625 [00:03<00:00, 200.97it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.3): 100%|██████████| 850/850 [00:10<00:00, 82.05it/s]
# test_batch (Avg. Loss 1.086, Accuracy 60.5): 100%|██████████| 625/625 [00:03<00:00, 193.92it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.929, Accuracy 67.1): 100%|██████████| 850/850 [00:10<00:00, 82.27it/s]
# test_batch (Avg. Loss 1.073, Accuracy 62.1): 100%|██████████| 625/625 [00:03<00:00, 197.18it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.891, Accuracy 68.4): 100%|██████████| 850/850 [00:10<00:00, 82.65it/s]
# test_batch (Avg. Loss 1.020, Accuracy 63.2): 100%|██████████| 625/625 [00:03<00:00, 199.97it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.858, Accuracy 69.7): 100%|██████████| 850/850 [00:10<00:00, 81.71it/s]
# test_batch (Avg. Loss 1.029, Accuracy 63.1): 100%|██████████| 625/625 [00:03<00:00, 202.86it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.823, Accuracy 70.8): 100%|██████████| 850/850 [00:10<00:00, 81.92it/s]
# test_batch (Avg. Loss 0.991, Accuracy 65.0): 100%|██████████| 625/625 [00:03<00:00, 198.45it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.791, Accuracy 72.2): 100%|██████████| 850/850 [00:10<00:00, 80.46it/s]
# test_batch (Avg. Loss 1.035, Accuracy 63.3): 100%|██████████| 625/625 [00:02<00:00, 209.43it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.767, Accuracy 73.1): 100%|██████████| 850/850 [00:10<00:00, 80.70it/s]
# test_batch (Avg. Loss 1.008, Accuracy 64.6): 100%|██████████| 625/625 [00:03<00:00, 200.10it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.738, Accuracy 73.9): 100%|██████████| 850/850 [00:10<00:00, 82.50it/s]
# test_batch (Avg. Loss 1.026, Accuracy 64.0): 100%|██████████| 625/625 [00:03<00:00, 205.38it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.712, Accuracy 75.0): 100%|██████████| 850/850 [00:10<00:00, 82.74it/s]
# test_batch (Avg. Loss 1.013, Accuracy 64.8): 100%|██████████| 625/625 [00:02<00:00, 211.77it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.688, Accuracy 75.8): 100%|██████████| 850/850 [00:10<00:00, 81.92it/s]
# test_batch (Avg. Loss 1.061, Accuracy 62.9): 100%|██████████| 625/625 [00:02<00:00, 217.90it/s]
# test_batch (Avg. Loss 1.057, Accuracy 63.2): 100%|██████████| 834/834 [00:06<00:00, 128.78it/s]
# ==================== Test Results ====================
# Test Accuracy: 63.16
# Test Loss: 1.0574256533520112
# ======================================================
# *** Output file ./results/exp1_2_L2_K64.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=131072, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.625, Accuracy 40.8): 100%|██████████| 850/850 [00:15<00:00, 53.25it/s]
# test_batch (Avg. Loss 1.404, Accuracy 47.9): 100%|██████████| 625/625 [00:03<00:00, 183.49it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.370, Accuracy 50.8): 100%|██████████| 850/850 [00:16<00:00, 52.53it/s]
# test_batch (Avg. Loss 1.385, Accuracy 50.6): 100%|██████████| 625/625 [00:03<00:00, 182.43it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.268, Accuracy 54.8): 100%|██████████| 850/850 [00:16<00:00, 51.97it/s]
# test_batch (Avg. Loss 1.293, Accuracy 52.6): 100%|██████████| 625/625 [00:03<00:00, 192.97it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.205, Accuracy 57.0): 100%|██████████| 850/850 [00:16<00:00, 52.68it/s]
# test_batch (Avg. Loss 1.281, Accuracy 54.4): 100%|██████████| 625/625 [00:03<00:00, 189.85it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.163, Accuracy 58.6): 100%|██████████| 850/850 [00:16<00:00, 52.68it/s]
# test_batch (Avg. Loss 1.227, Accuracy 55.4): 100%|██████████| 625/625 [00:03<00:00, 172.68it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.121, Accuracy 59.9): 100%|██████████| 850/850 [00:16<00:00, 52.91it/s]
# test_batch (Avg. Loss 1.180, Accuracy 58.0): 100%|██████████| 625/625 [00:03<00:00, 193.56it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.085, Accuracy 61.4): 100%|██████████| 850/850 [00:15<00:00, 53.52it/s]
# test_batch (Avg. Loss 1.231, Accuracy 55.5): 100%|██████████| 625/625 [00:03<00:00, 192.84it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 1.055, Accuracy 62.5): 100%|██████████| 850/850 [00:16<00:00, 52.77it/s]
# test_batch (Avg. Loss 1.111, Accuracy 60.2): 100%|██████████| 625/625 [00:03<00:00, 185.86it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 1.030, Accuracy 63.5): 100%|██████████| 850/850 [00:16<00:00, 52.24it/s]
# test_batch (Avg. Loss 1.103, Accuracy 60.8): 100%|██████████| 625/625 [00:03<00:00, 191.76it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.995, Accuracy 64.3): 100%|██████████| 850/850 [00:16<00:00, 52.84it/s]
# test_batch (Avg. Loss 1.140, Accuracy 59.3): 100%|██████████| 625/625 [00:03<00:00, 195.93it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.973, Accuracy 65.3): 100%|██████████| 850/850 [00:16<00:00, 53.06it/s]
# test_batch (Avg. Loss 1.103, Accuracy 60.4): 100%|██████████| 625/625 [00:03<00:00, 193.12it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.947, Accuracy 66.2): 100%|██████████| 850/850 [00:15<00:00, 53.22it/s]
# test_batch (Avg. Loss 1.059, Accuracy 62.5): 100%|██████████| 625/625 [00:03<00:00, 194.84it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.921, Accuracy 67.4): 100%|██████████| 850/850 [00:16<00:00, 53.00it/s]
# test_batch (Avg. Loss 1.071, Accuracy 61.6): 100%|██████████| 625/625 [00:03<00:00, 197.17it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.912, Accuracy 67.4): 100%|██████████| 850/850 [00:15<00:00, 53.25it/s]
# test_batch (Avg. Loss 1.066, Accuracy 62.1): 100%|██████████| 625/625 [00:03<00:00, 194.72it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.880, Accuracy 68.6): 100%|██████████| 850/850 [00:16<00:00, 52.89it/s]
# test_batch (Avg. Loss 1.059, Accuracy 61.9): 100%|██████████| 625/625 [00:03<00:00, 191.29it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.873, Accuracy 68.9): 100%|██████████| 850/850 [00:16<00:00, 52.29it/s]
# test_batch (Avg. Loss 1.082, Accuracy 61.8): 100%|██████████| 625/625 [00:03<00:00, 198.97it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.852, Accuracy 69.9): 100%|██████████| 850/850 [00:16<00:00, 52.98it/s]
# test_batch (Avg. Loss 1.050, Accuracy 62.7): 100%|██████████| 625/625 [00:03<00:00, 203.69it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.842, Accuracy 70.1): 100%|██████████| 850/850 [00:16<00:00, 52.86it/s]
# test_batch (Avg. Loss 1.036, Accuracy 63.1): 100%|██████████| 625/625 [00:03<00:00, 192.06it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.819, Accuracy 70.9): 100%|██████████| 850/850 [00:15<00:00, 53.14it/s]
# test_batch (Avg. Loss 1.060, Accuracy 61.8): 100%|██████████| 625/625 [00:03<00:00, 199.87it/s]
# --- EPOCH 20/30 ---
# train_batch (Avg. Loss 0.808, Accuracy 71.2): 100%|██████████| 850/850 [00:16<00:00, 53.12it/s]
# test_batch (Avg. Loss 1.053, Accuracy 62.4): 100%|██████████| 625/625 [00:03<00:00, 194.56it/s]
# --- EPOCH 21/30 ---
# train_batch (Avg. Loss 0.784, Accuracy 72.2): 100%|██████████| 850/850 [00:15<00:00, 53.15it/s]
# test_batch (Avg. Loss 1.054, Accuracy 62.9): 100%|██████████| 625/625 [00:03<00:00, 200.50it/s]
# --- EPOCH 22/30 ---
# train_batch (Avg. Loss 0.768, Accuracy 72.9): 100%|██████████| 850/850 [00:16<00:00, 52.28it/s]
# test_batch (Avg. Loss 1.046, Accuracy 63.3): 100%|██████████| 625/625 [00:03<00:00, 199.17it/s]
# --- EPOCH 23/30 ---
# train_batch (Avg. Loss 0.764, Accuracy 72.9): 100%|██████████| 850/850 [00:15<00:00, 53.25it/s]
# test_batch (Avg. Loss 1.063, Accuracy 62.3): 100%|██████████| 625/625 [00:03<00:00, 204.57it/s]
# test_batch (Avg. Loss 1.080, Accuracy 62.7): 100%|██████████| 834/834 [00:07<00:00, 113.92it/s]
# ==================== Test Results ====================
# Test Accuracy: 62.68
# Test Loss: 1.079726702053484
# ======================================================
# *** Output file ./results/exp1_2_L2_K128.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=262144, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.651, Accuracy 40.2): 100%|██████████| 850/850 [00:34<00:00, 24.68it/s]
# test_batch (Avg. Loss 1.430, Accuracy 48.0): 100%|██████████| 625/625 [00:03<00:00, 157.55it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.353, Accuracy 51.3): 100%|██████████| 850/850 [00:34<00:00, 24.88it/s]
# test_batch (Avg. Loss 1.264, Accuracy 54.1): 100%|██████████| 625/625 [00:03<00:00, 160.52it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.245, Accuracy 55.4): 100%|██████████| 850/850 [00:33<00:00, 25.31it/s]
# test_batch (Avg. Loss 1.233, Accuracy 55.1): 100%|██████████| 625/625 [00:04<00:00, 156.07it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.179, Accuracy 57.6): 100%|██████████| 850/850 [00:33<00:00, 25.07it/s]
# test_batch (Avg. Loss 1.160, Accuracy 58.2): 100%|██████████| 625/625 [00:03<00:00, 158.18it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.138, Accuracy 59.0): 100%|██████████| 850/850 [00:33<00:00, 25.18it/s]
# test_batch (Avg. Loss 1.165, Accuracy 58.1): 100%|██████████| 625/625 [00:04<00:00, 155.91it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.105, Accuracy 60.7): 100%|██████████| 850/850 [00:33<00:00, 25.21it/s]
# test_batch (Avg. Loss 1.196, Accuracy 56.5): 100%|██████████| 625/625 [00:03<00:00, 157.20it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.084, Accuracy 61.3): 100%|██████████| 850/850 [00:33<00:00, 25.21it/s]
# test_batch (Avg. Loss 1.180, Accuracy 57.7): 100%|██████████| 625/625 [00:03<00:00, 163.39it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 1.054, Accuracy 62.2): 100%|██████████| 850/850 [00:33<00:00, 25.25it/s]
# test_batch (Avg. Loss 1.134, Accuracy 59.7): 100%|██████████| 625/625 [00:03<00:00, 163.26it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 1.027, Accuracy 63.3): 100%|██████████| 850/850 [00:33<00:00, 25.38it/s]
# test_batch (Avg. Loss 1.134, Accuracy 59.6): 100%|██████████| 625/625 [00:03<00:00, 165.09it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 1.003, Accuracy 64.3): 100%|██████████| 850/850 [00:33<00:00, 25.32it/s]
# test_batch (Avg. Loss 1.124, Accuracy 60.1): 100%|██████████| 625/625 [00:03<00:00, 160.92it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.975, Accuracy 65.3): 100%|██████████| 850/850 [00:33<00:00, 25.43it/s]
# test_batch (Avg. Loss 1.115, Accuracy 59.6): 100%|██████████| 625/625 [00:03<00:00, 159.75it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.952, Accuracy 65.9): 100%|██████████| 850/850 [00:33<00:00, 25.23it/s]
# test_batch (Avg. Loss 1.194, Accuracy 58.0): 100%|██████████| 625/625 [00:03<00:00, 165.30it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.924, Accuracy 67.2): 100%|██████████| 850/850 [00:33<00:00, 25.36it/s]
# test_batch (Avg. Loss 1.133, Accuracy 59.2): 100%|██████████| 625/625 [00:03<00:00, 163.36it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.903, Accuracy 67.9): 100%|██████████| 850/850 [00:33<00:00, 25.38it/s]
# test_batch (Avg. Loss 1.081, Accuracy 61.9): 100%|██████████| 625/625 [00:03<00:00, 165.85it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.878, Accuracy 68.7): 100%|██████████| 850/850 [00:33<00:00, 25.09it/s]
# test_batch (Avg. Loss 1.095, Accuracy 60.5): 100%|██████████| 625/625 [00:03<00:00, 160.83it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.853, Accuracy 69.7): 100%|██████████| 850/850 [00:33<00:00, 25.09it/s]
# test_batch (Avg. Loss 1.094, Accuracy 62.1): 100%|██████████| 625/625 [00:03<00:00, 163.96it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.833, Accuracy 70.2): 100%|██████████| 850/850 [00:33<00:00, 25.42it/s]
# test_batch (Avg. Loss 1.090, Accuracy 61.9): 100%|██████████| 625/625 [00:03<00:00, 158.05it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.812, Accuracy 71.2): 100%|██████████| 850/850 [00:33<00:00, 25.22it/s]
# test_batch (Avg. Loss 1.119, Accuracy 60.9): 100%|██████████| 625/625 [00:03<00:00, 160.45it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.784, Accuracy 72.2): 100%|██████████| 850/850 [00:33<00:00, 25.33it/s]
# test_batch (Avg. Loss 1.135, Accuracy 60.0): 100%|██████████| 625/625 [00:03<00:00, 162.53it/s]
# test_batch (Avg. Loss 1.133, Accuracy 60.7): 100%|██████████| 834/834 [00:07<00:00, 107.50it/s]
# ==================== Test Results ====================
# Test Accuracy: 60.72
# Test Loss: 1.1332158663218541
# ======================================================
# *** Output file ./results/exp1_2_L2_K256.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.731, Accuracy 36.0): 100%|██████████| 850/850 [00:08<00:00, 96.60it/s]
# test_batch (Avg. Loss 1.534, Accuracy 43.4): 100%|██████████| 625/625 [00:03<00:00, 206.62it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.434, Accuracy 47.7): 100%|██████████| 850/850 [00:08<00:00, 95.69it/s]
# test_batch (Avg. Loss 1.343, Accuracy 50.1): 100%|██████████| 625/625 [00:03<00:00, 200.39it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.271, Accuracy 54.2): 100%|██████████| 850/850 [00:08<00:00, 94.46it/s]
# test_batch (Avg. Loss 1.197, Accuracy 56.2): 100%|██████████| 625/625 [00:03<00:00, 206.75it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.165, Accuracy 58.3): 100%|██████████| 850/850 [00:08<00:00, 94.69it/s]
# test_batch (Avg. Loss 1.098, Accuracy 61.0): 100%|██████████| 625/625 [00:03<00:00, 200.44it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.095, Accuracy 61.0): 100%|██████████| 850/850 [00:08<00:00, 95.16it/s]
# test_batch (Avg. Loss 1.114, Accuracy 60.3): 100%|██████████| 625/625 [00:03<00:00, 197.82it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 1.044, Accuracy 62.6): 100%|██████████| 850/850 [00:08<00:00, 96.38it/s]
# test_batch (Avg. Loss 1.076, Accuracy 62.0): 100%|██████████| 625/625 [00:03<00:00, 205.33it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.012, Accuracy 64.1): 100%|██████████| 850/850 [00:08<00:00, 98.56it/s]
# test_batch (Avg. Loss 1.038, Accuracy 62.9): 100%|██████████| 625/625 [00:03<00:00, 204.74it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.977, Accuracy 65.2): 100%|██████████| 850/850 [00:08<00:00, 96.24it/s]
# test_batch (Avg. Loss 1.056, Accuracy 62.7): 100%|██████████| 625/625 [00:03<00:00, 197.91it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.937, Accuracy 66.5): 100%|██████████| 850/850 [00:08<00:00, 95.79it/s]
# test_batch (Avg. Loss 1.110, Accuracy 60.9): 100%|██████████| 625/625 [00:03<00:00, 204.00it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.914, Accuracy 67.3): 100%|██████████| 850/850 [00:08<00:00, 95.81it/s]
# test_batch (Avg. Loss 0.989, Accuracy 65.3): 100%|██████████| 625/625 [00:03<00:00, 203.36it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.888, Accuracy 68.5): 100%|██████████| 850/850 [00:08<00:00, 98.40it/s]
# test_batch (Avg. Loss 1.031, Accuracy 63.3): 100%|██████████| 625/625 [00:03<00:00, 200.76it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.857, Accuracy 69.5): 100%|██████████| 850/850 [00:08<00:00, 94.91it/s]
# test_batch (Avg. Loss 1.072, Accuracy 62.3): 100%|██████████| 625/625 [00:03<00:00, 198.11it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.832, Accuracy 70.4): 100%|██████████| 850/850 [00:08<00:00, 96.93it/s]
# test_batch (Avg. Loss 0.938, Accuracy 67.1): 100%|██████████| 625/625 [00:03<00:00, 197.91it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.807, Accuracy 71.3): 100%|██████████| 850/850 [00:08<00:00, 98.24it/s]
# test_batch (Avg. Loss 0.962, Accuracy 65.7): 100%|██████████| 625/625 [00:03<00:00, 198.34it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.793, Accuracy 71.9): 100%|██████████| 850/850 [00:08<00:00, 95.41it/s]
# test_batch (Avg. Loss 0.963, Accuracy 66.6): 100%|██████████| 625/625 [00:03<00:00, 197.86it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.773, Accuracy 72.4): 100%|██████████| 850/850 [00:08<00:00, 97.94it/s]
# test_batch (Avg. Loss 0.987, Accuracy 65.8): 100%|██████████| 625/625 [00:03<00:00, 200.77it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.743, Accuracy 73.8): 100%|██████████| 850/850 [00:08<00:00, 96.96it/s]
# test_batch (Avg. Loss 1.003, Accuracy 65.8): 100%|██████████| 625/625 [00:03<00:00, 194.60it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.725, Accuracy 74.2): 100%|██████████| 850/850 [00:09<00:00, 94.43it/s]
# test_batch (Avg. Loss 0.979, Accuracy 66.4): 100%|██████████| 625/625 [00:03<00:00, 200.84it/s]
# test_batch (Avg. Loss 0.992, Accuracy 65.4): 100%|██████████| 834/834 [00:06<00:00, 137.32it/s]
# ==================== Test Results ====================
# Test Accuracy: 65.43
# Test Loss: 0.9919064971361514
# ======================================================
# *** Output file ./results/exp1_2_L4_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.734, Accuracy 35.9): 100%|██████████| 850/850 [00:13<00:00, 64.35it/s]
# test_batch (Avg. Loss 1.519, Accuracy 43.9): 100%|██████████| 625/625 [00:03<00:00, 200.37it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.413, Accuracy 48.6): 100%|██████████| 850/850 [00:13<00:00, 63.50it/s]
# test_batch (Avg. Loss 1.314, Accuracy 51.1): 100%|██████████| 625/625 [00:03<00:00, 193.99it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.257, Accuracy 54.9): 100%|██████████| 850/850 [00:13<00:00, 63.48it/s]
# test_batch (Avg. Loss 1.195, Accuracy 56.9): 100%|██████████| 625/625 [00:03<00:00, 195.41it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.144, Accuracy 59.1): 100%|██████████| 850/850 [00:13<00:00, 62.79it/s]
# test_batch (Avg. Loss 1.110, Accuracy 61.1): 100%|██████████| 625/625 [00:03<00:00, 200.65it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 1.053, Accuracy 62.5): 100%|██████████| 850/850 [00:13<00:00, 63.95it/s]
# test_batch (Avg. Loss 1.112, Accuracy 60.7): 100%|██████████| 625/625 [00:03<00:00, 199.55it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.981, Accuracy 65.1): 100%|██████████| 850/850 [00:13<00:00, 63.87it/s]
# test_batch (Avg. Loss 1.073, Accuracy 62.1): 100%|██████████| 625/625 [00:03<00:00, 201.65it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.925, Accuracy 67.3): 100%|██████████| 850/850 [00:13<00:00, 63.87it/s]
# test_batch (Avg. Loss 0.957, Accuracy 66.3): 100%|██████████| 625/625 [00:03<00:00, 205.55it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.869, Accuracy 69.3): 100%|██████████| 850/850 [00:13<00:00, 63.46it/s]
# test_batch (Avg. Loss 1.017, Accuracy 64.3): 100%|██████████| 625/625 [00:03<00:00, 207.23it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.831, Accuracy 70.4): 100%|██████████| 850/850 [00:13<00:00, 63.75it/s]
# test_batch (Avg. Loss 0.942, Accuracy 67.2): 100%|██████████| 625/625 [00:03<00:00, 203.84it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.792, Accuracy 72.1): 100%|██████████| 850/850 [00:13<00:00, 63.51it/s]
# test_batch (Avg. Loss 0.987, Accuracy 65.9): 100%|██████████| 625/625 [00:03<00:00, 197.25it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.761, Accuracy 73.0): 100%|██████████| 850/850 [00:13<00:00, 62.27it/s]
# test_batch (Avg. Loss 0.940, Accuracy 67.4): 100%|██████████| 625/625 [00:03<00:00, 201.17it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.721, Accuracy 74.7): 100%|██████████| 850/850 [00:13<00:00, 63.48it/s]
# test_batch (Avg. Loss 0.927, Accuracy 67.9): 100%|██████████| 625/625 [00:03<00:00, 207.29it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.696, Accuracy 75.5): 100%|██████████| 850/850 [00:13<00:00, 64.37it/s]
# test_batch (Avg. Loss 0.903, Accuracy 68.2): 100%|██████████| 625/625 [00:03<00:00, 193.52it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.664, Accuracy 76.5): 100%|██████████| 850/850 [00:13<00:00, 63.32it/s]
# test_batch (Avg. Loss 0.932, Accuracy 68.3): 100%|██████████| 625/625 [00:03<00:00, 195.20it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.642, Accuracy 77.4): 100%|██████████| 850/850 [00:13<00:00, 63.77it/s]
# test_batch (Avg. Loss 0.924, Accuracy 68.2): 100%|██████████| 625/625 [00:03<00:00, 198.29it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.620, Accuracy 78.0): 100%|██████████| 850/850 [00:13<00:00, 63.68it/s]
# test_batch (Avg. Loss 0.995, Accuracy 67.4): 100%|██████████| 625/625 [00:03<00:00, 200.41it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 0.599, Accuracy 78.6): 100%|██████████| 850/850 [00:13<00:00, 63.31it/s]
# test_batch (Avg. Loss 0.998, Accuracy 67.4): 100%|██████████| 625/625 [00:03<00:00, 196.50it/s]
# --- EPOCH 18/30 ---
# train_batch (Avg. Loss 0.579, Accuracy 79.3): 100%|██████████| 850/850 [00:13<00:00, 61.42it/s]
# test_batch (Avg. Loss 0.926, Accuracy 68.6): 100%|██████████| 625/625 [00:03<00:00, 199.39it/s]
# test_batch (Avg. Loss 0.947, Accuracy 68.4): 100%|██████████| 834/834 [00:06<00:00, 126.15it/s]
# ==================== Test Results ====================
# Test Accuracy: 68.38
# Test Loss: 0.9467311977661199
# ======================================================
# *** Output file ./results/exp1_2_L4_K64.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=32768, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.717, Accuracy 36.7): 100%|██████████| 850/850 [00:23<00:00, 36.28it/s]
# test_batch (Avg. Loss 1.454, Accuracy 46.8): 100%|██████████| 625/625 [00:03<00:00, 170.08it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.340, Accuracy 51.5): 100%|██████████| 850/850 [00:23<00:00, 35.92it/s]
# test_batch (Avg. Loss 1.299, Accuracy 53.7): 100%|██████████| 625/625 [00:03<00:00, 166.92it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.127, Accuracy 59.8): 100%|██████████| 850/850 [00:23<00:00, 36.36it/s]
# test_batch (Avg. Loss 1.101, Accuracy 61.1): 100%|██████████| 625/625 [00:03<00:00, 170.52it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 0.993, Accuracy 64.8): 100%|██████████| 850/850 [00:23<00:00, 36.11it/s]
# test_batch (Avg. Loss 0.993, Accuracy 64.3): 100%|██████████| 625/625 [00:03<00:00, 176.65it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.896, Accuracy 68.1): 100%|██████████| 850/850 [00:23<00:00, 36.40it/s]
# test_batch (Avg. Loss 0.967, Accuracy 65.8): 100%|██████████| 625/625 [00:03<00:00, 173.74it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.835, Accuracy 70.7): 100%|██████████| 850/850 [00:23<00:00, 36.34it/s]
# test_batch (Avg. Loss 0.981, Accuracy 65.4): 100%|██████████| 625/625 [00:03<00:00, 175.87it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.780, Accuracy 72.5): 100%|██████████| 850/850 [00:23<00:00, 36.30it/s]
# test_batch (Avg. Loss 0.907, Accuracy 67.7): 100%|██████████| 625/625 [00:03<00:00, 166.20it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.736, Accuracy 74.0): 100%|██████████| 850/850 [00:23<00:00, 35.99it/s]
# test_batch (Avg. Loss 0.908, Accuracy 68.2): 100%|██████████| 625/625 [00:03<00:00, 171.21it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.696, Accuracy 75.5): 100%|██████████| 850/850 [00:23<00:00, 36.56it/s]
# test_batch (Avg. Loss 0.906, Accuracy 69.2): 100%|██████████| 625/625 [00:03<00:00, 171.27it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.662, Accuracy 76.7): 100%|██████████| 850/850 [00:23<00:00, 36.48it/s]
# test_batch (Avg. Loss 0.929, Accuracy 67.4): 100%|██████████| 625/625 [00:03<00:00, 179.18it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.629, Accuracy 77.7): 100%|██████████| 850/850 [00:23<00:00, 36.25it/s]
# test_batch (Avg. Loss 0.902, Accuracy 68.8): 100%|██████████| 625/625 [00:03<00:00, 175.46it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.590, Accuracy 79.2): 100%|██████████| 850/850 [00:23<00:00, 36.20it/s]
# test_batch (Avg. Loss 0.971, Accuracy 67.5): 100%|██████████| 625/625 [00:03<00:00, 171.04it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.564, Accuracy 79.9): 100%|██████████| 850/850 [00:23<00:00, 36.15it/s]
# test_batch (Avg. Loss 0.951, Accuracy 67.6): 100%|██████████| 625/625 [00:03<00:00, 170.14it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.537, Accuracy 81.1): 100%|██████████| 850/850 [00:23<00:00, 36.48it/s]
# test_batch (Avg. Loss 0.957, Accuracy 68.3): 100%|██████████| 625/625 [00:03<00:00, 170.31it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.509, Accuracy 81.8): 100%|██████████| 850/850 [00:23<00:00, 36.31it/s]
# test_batch (Avg. Loss 0.940, Accuracy 68.7): 100%|██████████| 625/625 [00:03<00:00, 165.77it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.490, Accuracy 82.5): 100%|██████████| 850/850 [00:23<00:00, 36.44it/s]
# test_batch (Avg. Loss 0.945, Accuracy 69.1): 100%|██████████| 625/625 [00:03<00:00, 173.06it/s]
# test_batch (Avg. Loss 0.969, Accuracy 69.2): 100%|██████████| 834/834 [00:07<00:00, 118.11it/s]
# ==================== Test Results ====================
# Test Accuracy: 69.16
# Test Loss: 0.9687947006203788
# ======================================================
# *** Output file ./results/exp1_2_L4_K128.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=65536, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 1.716, Accuracy 36.9): 100%|██████████| 850/850 [00:59<00:00, 14.23it/s]
# test_batch (Avg. Loss 1.471, Accuracy 46.7): 100%|██████████| 625/625 [00:05<00:00, 109.37it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 1.360, Accuracy 51.1): 100%|██████████| 850/850 [00:59<00:00, 14.40it/s]
# test_batch (Avg. Loss 1.293, Accuracy 53.2): 100%|██████████| 625/625 [00:05<00:00, 111.34it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 1.189, Accuracy 57.4): 100%|██████████| 850/850 [00:58<00:00, 14.46it/s]
# test_batch (Avg. Loss 1.138, Accuracy 59.4): 100%|██████████| 625/625 [00:05<00:00, 112.15it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 1.033, Accuracy 63.3): 100%|██████████| 850/850 [00:58<00:00, 14.44it/s]
# test_batch (Avg. Loss 1.088, Accuracy 62.6): 100%|██████████| 625/625 [00:05<00:00, 114.02it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 0.936, Accuracy 66.8): 100%|██████████| 850/850 [00:58<00:00, 14.48it/s]
# test_batch (Avg. Loss 0.983, Accuracy 65.5): 100%|██████████| 625/625 [00:05<00:00, 110.15it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 0.861, Accuracy 69.6): 100%|██████████| 850/850 [00:58<00:00, 14.49it/s]
# test_batch (Avg. Loss 0.955, Accuracy 66.3): 100%|██████████| 625/625 [00:05<00:00, 109.58it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 0.811, Accuracy 71.3): 100%|██████████| 850/850 [00:58<00:00, 14.46it/s]
# test_batch (Avg. Loss 0.889, Accuracy 68.6): 100%|██████████| 625/625 [00:05<00:00, 107.64it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 0.764, Accuracy 73.3): 100%|██████████| 850/850 [00:58<00:00, 14.46it/s]
# test_batch (Avg. Loss 0.947, Accuracy 66.4): 100%|██████████| 625/625 [00:05<00:00, 111.38it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 0.722, Accuracy 74.6): 100%|██████████| 850/850 [00:58<00:00, 14.45it/s]
# test_batch (Avg. Loss 0.957, Accuracy 66.8): 100%|██████████| 625/625 [00:05<00:00, 110.67it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 0.685, Accuracy 75.8): 100%|██████████| 850/850 [00:58<00:00, 14.46it/s]
# test_batch (Avg. Loss 0.943, Accuracy 67.3): 100%|██████████| 625/625 [00:05<00:00, 110.18it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 0.652, Accuracy 77.0): 100%|██████████| 850/850 [00:58<00:00, 14.44it/s]
# test_batch (Avg. Loss 0.875, Accuracy 70.0): 100%|██████████| 625/625 [00:05<00:00, 109.82it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 0.615, Accuracy 78.2): 100%|██████████| 850/850 [00:58<00:00, 14.48it/s]
# test_batch (Avg. Loss 0.895, Accuracy 69.7): 100%|██████████| 625/625 [00:05<00:00, 109.26it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.585, Accuracy 79.3): 100%|██████████| 850/850 [00:58<00:00, 14.47it/s]
# test_batch (Avg. Loss 0.968, Accuracy 67.8): 100%|██████████| 625/625 [00:05<00:00, 113.09it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 0.560, Accuracy 80.3): 100%|██████████| 850/850 [00:58<00:00, 14.48it/s]
# test_batch (Avg. Loss 0.952, Accuracy 68.0): 100%|██████████| 625/625 [00:05<00:00, 106.67it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 0.529, Accuracy 81.0): 100%|██████████| 850/850 [00:58<00:00, 14.51it/s]
# test_batch (Avg. Loss 0.892, Accuracy 69.6): 100%|██████████| 625/625 [00:05<00:00, 111.02it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 0.503, Accuracy 82.0): 100%|██████████| 850/850 [00:58<00:00, 14.47it/s]
# test_batch (Avg. Loss 0.987, Accuracy 67.5): 100%|██████████| 625/625 [00:05<00:00, 109.08it/s]
# test_batch (Avg. Loss 0.993, Accuracy 67.6): 100%|██████████| 834/834 [00:09<00:00, 86.53it/s]
# ==================== Test Results ====================
# Test Accuracy: 67.6
# Test Loss: 0.993242030521091
# ======================================================
# *** Output file ./results/exp1_2_L4_K256.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=2048, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:10<00:00, 78.27it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:03<00:00, 188.40it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:10<00:00, 78.27it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 170.92it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:11<00:00, 75.92it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 170.76it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:10<00:00, 78.12it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 173.20it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:11<00:00, 76.01it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 168.58it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:11<00:00, 74.05it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 172.99it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 122.78it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.3026346871607024
# ======================================================
# *** Output file ./results/exp1_2_L8_K32.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:16<00:00, 52.73it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.5): 100%|██████████| 625/625 [00:03<00:00, 170.00it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:16<00:00, 52.86it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 173.56it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:15<00:00, 53.16it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 179.97it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [00:15<00:00, 53.66it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 170.25it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:16<00:00, 52.53it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 177.48it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:15<00:00, 54.04it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 180.54it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:06<00:00, 119.73it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.3026180813352553
# ======================================================
# *** Output file ./results/exp1_2_L8_K64.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=8192, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:34<00:00, 24.75it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:04<00:00, 153.58it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:33<00:00, 25.46it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 160.05it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:33<00:00, 25.02it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 158.34it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 850/850 [00:34<00:00, 24.87it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:03<00:00, 158.98it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:34<00:00, 24.97it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 159.00it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.58it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:04<00:00, 145.45it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:34<00:00, 24.64it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:03<00:00, 156.34it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.44it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 625/625 [00:04<00:00, 152.12it/s]
# --- EPOCH 9/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:34<00:00, 24.46it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:04<00:00, 154.15it/s]
# --- EPOCH 10/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:34<00:00, 24.50it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:04<00:00, 153.38it/s]
# --- EPOCH 11/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.46it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:03<00:00, 156.47it/s]
# --- EPOCH 12/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:34<00:00, 24.47it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 625/625 [00:04<00:00, 155.48it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.42it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:03<00:00, 156.59it/s]
# --- EPOCH 14/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [00:34<00:00, 24.45it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 159.14it/s]
# --- EPOCH 15/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.48it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 162.07it/s]
# --- EPOCH 16/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [00:34<00:00, 24.40it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 158.05it/s]
# --- EPOCH 17/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [00:34<00:00, 24.39it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:03<00:00, 157.38it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:07<00:00, 104.39it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.3026706769312026
# ======================================================
# *** Output file ./results/exp1_2_L8_K128.json written
# Files already downloaded and verified
# Files already downloaded and verified
# ConvClassifier(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (14): ReLU()
#     (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU()
#     (17): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=16384, out_features=100, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=100, out_features=100, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=100, out_features=10, bias=True)
#   )
# )
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [01:14<00:00, 11.39it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:06<00:00, 91.28it/s]
# --- EPOCH 2/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.1): 100%|██████████| 850/850 [01:12<00:00, 11.79it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 91.13it/s]
# --- EPOCH 3/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 850/850 [01:15<00:00, 11.24it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.3): 100%|██████████| 625/625 [00:06<00:00, 90.84it/s]
# --- EPOCH 4/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [01:15<00:00, 11.23it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 90.53it/s]
# --- EPOCH 5/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [01:16<00:00, 11.18it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.6): 100%|██████████| 625/625 [00:06<00:00, 89.85it/s]
# --- EPOCH 6/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [01:16<00:00, 11.16it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:06<00:00, 90.21it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.9): 100%|██████████| 850/850 [01:16<00:00, 11.07it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 625/625 [00:06<00:00, 90.68it/s]
# --- EPOCH 8/30 ---
# train_batch (Avg. Loss 2.303, Accuracy 9.8): 100%|██████████| 850/850 [01:15<00:00, 11.20it/s]
# test_batch (Avg. Loss 2.303, Accuracy 9.7): 100%|██████████| 625/625 [00:06<00:00, 90.74it/s]
# test_batch (Avg. Loss 2.303, Accuracy 10.0): 100%|██████████| 834/834 [00:11<00:00, 73.84it/s]
# ==================== Test Results ====================
# Test Accuracy: 10.0
# Test Loss: 2.3026327466507324
# ======================================================
# *** Output file ./results/exp1_2_L8_K256.json written

# %%
plot_exp_results('exp1_2_L2*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L2_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
plot_exp_results('exp1_2_L4*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L4_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %%
plot_exp_results('exp1_2_L8*.json')
# Out:
# common config:  {'run_name': 'exp1_2_L8_K64', 'out_dir': './results', 'seed': 42, 'bs_train': 50, 'bs_test': 12, 'batches': 10000, 'epochs': 30, 'early_stopping': 5, 'checkpoints': None, 'lr': 0.001, 'reg': 0.002, 'pool_every': 4, 'hidden_dims': [100, 100], 'ycn': False, 'kw': {}}

# %% [markdown]
# ### Question 2
#
# Analyze your results from experiment 1.2. In particular, compare to the results of experiment 1.1. For a spesific value of L, how the preformance change with respect to K? Does we saw the same phenomena in 1.1 for a spresific value of K?

# %% [markdown]
# **ANSWER**:
#
# As we can see, regarding the 2-layer nets, there was no significant improvement in accuracy on the test set when using kernel of sizes 32, 64, and 128 predicting accurate results in about 63% of the test samples. Surprisingly, the 2-layer net with the kernel of size 256 was 2-2.5% less accurate on the test set.
# In addition, we see that all the nets reached a much higher training accuracy, about 13% higher for each of the nets, indicating that they overfit the training data.
#
# Next, regarding the 4-layer nets, we see that the net with kernel of size 128 performed best with 69.2%, followed by the net with kernel if size 64 with 68.4%, and the net with kernel of size 256 with 67.6%. At last, we see that the net with kernel of size 32 performed the worst with 65.4 which is relatively low for the 4-layer nets.
# Also, we can see that those nets are overfitting the training data as well as the 2-layer nets, due to the large margin between the training results and the test results.
#
# On the other size, we can obviously see that in general, the 4-layer net performed better than the 2-layer nets and produced more accurated test results. That is true in both 1.1 and 1.2 experiments for every kernel size.
#
# At last, we can see that in the current experiemnt as well as in the previous one, all the nets with 8 or more layers were untrainable, regardless of the kernel size.
